# %%
###################
## Load packages ##
###################
import requests
import json
import pandas as pd
import numpy as np
import covalent_api as c
import matplotlib.pyplot as plt
from pandas.plotting import lag_plot
import datetime
from statsmodels.tsa.arima_model import ARIMA
import pmdarima as pm
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import adfuller
from sklearn.metrics import accuracy_score, r2_score, precision_score
from PIL import Image
import requests
from io import BytesIO
plt.rcParams.update({'figure.figsize':(9,7), 'figure.dpi':120})
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <cell line: 8>()
#       6 import pandas as pd
#       7 import numpy as np
# ----> 8 import covalent_api as c
#       9 import matplotlib.pyplot as plt
#      10 from pandas.plotting import lag_plot
#
# ModuleNotFoundError: No module named 'covalent_api'

# %%
####################
## Load functions ##
####################
def fetch_collection_hist(address):
    api_url = 'https://api.covalenthq.com'
    endpoint = f'/v1/1/nft_market/collection/{address}/'
    url = api_url + endpoint
    r = requests.get(url, auth=('ckey_e9bfb5c526384e90a9c1d53d154',''))
    input_data = r.json()
    print(input_data)
    input_data = input_data['data']['items']
    out = pd.DataFrame.from_records(input_data)
    return(out)

def fetch_token_id(address): 
    api_url = 'https://api.covalenthq.com'
    endpoint = f'/v1/1/tokens/{address}/nft_token_ids/'
    url = api_url + endpoint
    r = requests.get(url, auth=('ckey_e9bfb5c526384e90a9c1d53d154',''))
    input_data = r.json()
    return(input_data)

def fetch_token_tx(address, token_id):
    api_url = 'https://api.covalenthq.com'
    endpoint = f'/v1/1/tokens/{address}/nft_transactions/{token_id}/'
    url = api_url + endpoint
    r = requests.get(url, auth=('ckey_e9bfb5c526384e90a9c1d53d154',''))
    input_data = r.json()
    return(input_data)

def fetch_token_meta(address, token_id):
    api_url = 'https://api.covalenthq.com'
    endpoint = f'/v1/1/tokens/{address}/nft_metadata/{token_id}/'
    url = api_url + endpoint
    r = requests.get(url, auth=('ckey_e9bfb5c526384e90a9c1d53d154',''))
    input_data = r.json()
    input_data = input_data['data']['items'][0]['nft_data']
    out = pd.DataFrame.from_records(input_data)
    out_2 = pd.DataFrame.from_records(out['external_data'])
    out_table = pd.DataFrame({'token_id': out['token_id']
                              ,'token_balance': out['token_balance']
                              ,'image_url': out_2['image']
                              ,'traits': out_2['attributes']})

    trait = pd.DataFrame.from_records(out_table['traits'][0])
    trait.loc[:,'token_id'] = out_table['token_id']
    trait['token_id'] = out_table['token_id'].tolist() * len(trait)
    trait['image_url'] = out_table['image_url'].tolist() * len(trait)            
    return(trait)

def stationary_test(x):
    out = adfuller(x.dropna())
    print('ADF Statistic: %f' % out[0])
    print('p-value: %f' % out[1])
    if out[1] <= 0.05:
        print('Time-series is stationary at 5% significance level.')
    else:
        print('Time-series is non-stationary at 5% significance level. Find the order of difference!')

# Accuracy metrics
def accuracy(y_hat, y):
    mape = np.mean(np.abs(y_hat - y)/np.abs(y))     
    rmse = np.mean((y_hat - y)**2)**0.5
    corr = np.corrcoef(y_hat, y)[0,1]   

    return({'Mean absolute percentage error':mape
            , 'Root mean squared error':rmse
            , 'corr':corr})

# %%
################################################
## ༼ つ ◕_◕ ༽つ Input NFT contract address below: 
################################################
## (BAYC as an example here)
nft_address = '0xbc4ca0eda7647a8ab7c2061c2e118a18a936f13d'
###################################
## Read in historic floor prices ##
###################################

## Read in floor price 
data = fetch_collection_hist(nft_address)
data['opening_date'] = pd.to_datetime(data['opening_date'])
data = data.sort_values(by='opening_date', ascending=True)
data.set_index('opening_date', inplace=True)

## Plot floor price
name = np.unique(data['collection_name']).tolist()
plt.plot( data["floor_price_quote_7d"])
plt.title("Historical floor price "+str(name))
plt.xlabel("time")
plt.ylabel("price")
plt.show()
# Out:
# {'data': {'updated_at': '2022-11-11T19:29:16.605177185Z', 'items': [{'chain_id': 1, 'collection_name': 'BoredApeYachtClub', 'collection_address': '0xbc4ca0eda7647a8ab7c2061c2e118a18a936f13d', 'collection_ticker_symbol': 'BAYC', 'opening_date': '2022-04-06', 'volume_wei_day': '1243935000000000000000', 'volume_quote_day': 4165680.2, 'average_volume_wei_day': '113085000000000000000', 'average_volume_quote_day': 378698.2, 'unique_token_ids_sold_count_day': 10, 'floor_price_wei_7d': '121959295292299000000', 'floor_price_quote_7d': 408416.38, 'gas_quote_rate_day': 3348.7925, 'quote_currency': 'USD', 'first_nft_image_token_id': '0', 'first_nft_image': 'https://ipfs.io/ipfs/QmRRPWG96cmgTn2qSzjwr2qvfNEuhunv6FNeMFGa9bx6mQ', 'first_nft_image_256': 'https://image-proxy.svc.prod.covalenthq.com/cdn-cgi/image/width=256,fit/https://ipfs.io/ipfs/QmRRPWG96cmgTn2qSzjwr2qvfNEuhunv6FNeMFGa9bx6mQ', 'first_nft_image_512': 'https://image-proxy.svc.prod.covalenthq.com/cdn-cgi/image/width=512,fit/https://ipfs.io/ipfs/QmRRPWG96cmgTn2qSzjwr2qvfNEuhunv6FNeMFGa9bx6mQ', 'first_nft_image_1024': 'https://image-proxy.svc.prod.covalenthq.com/cdn-cgi/image/width=1024,fit/https://ipfs.io/ipfs/QmRRPWG96cmgTn2qSzjwr2qvfNEuhunv6FNeMFGa9bx6mQ', 'second_nft_image_token_id': '1', 'second_nft_image': 'https://ipfs.io/ipfs/QmPbxeGcXhYQQNgsC6a36dDyYUcHgMLnGKnF8pVFmGsvqi', 'second_nft_image_256': 'https://image-proxy.svc.prod.covalenthq.com/cdn-cgi/image/width=256,fit/https://ipfs.io/ipfs/QmPbxeGcXhYQQNgsC6a36dDyYUcHgMLnGKnF8pVFmGsvqi', 'second_nft_image_512': 'https://image-proxy.svc.prod.covalenthq.com/cdn-cgi/image/width=512,fit/https://ipfs.io/ipfs/QmPbxeGcXhYQQNgsC6a36dDyYUcHgMLnGKnF8pVFmGsvqi', 'second_nft_image_1024': 'https://image-proxy.svc.prod.covalenthq.com/cdn-cgi/image/width=1024,fit/https://ipfs.io/ipfs/QmPbxeGcXhYQQNgsC6a36dDyYUcHgMLnGKnF8pVFmGsvqi', 'third_nft_image_token_id': '2', 'third_nft_image': 'https://ipfs.io/ipfs/QmcJYkCKK7QPmYWjp4FD2e3Lv5WCGFuHNUByvGKBaytif4', 'third_nft_image_256': 'https://image-proxy.svc.prod.covalenthq.com/cdn-cgi/image/width=256,fit/https://ipfs.io/ipfs/QmcJYkCKK7QPmYWjp4FD2e3Lv5WCGFuHNUByvGKBaytif4', 'third_nft_image_512': 'https://image-proxy.svc.prod.covalenthq.com/cdn-cgi/image/width=512,fit/https://ipfs.io/ipfs/QmcJYkCKK7QPmYWjp4FD2e3Lv5WCGFuHNUByvGKBaytif4', 'third_nft_image_1024': 'https://image-proxy.svc.prod.covalenthq.com/cdn-cgi/image/width=1024,fit/https://ipfs.io/ipfs/QmcJYkCKK7QPmYWjp4FD2e3Lv5WCGFuHNUByvGKBaytif4', 'fourth_nft_image_token_id': '3', 'fourth_nft_image': 'https://ipfs.io/ipfs/QmYxT4LnK8sqLupjbS6eRvu1si7Ly2wFQAqFebxhWntcf6', 'fourth_nft_image_256': 'https://image-proxy.svc.prod.covalenthq.com/cdn-cgi/image/width=256,fit/https://ipfs.io/ipfs/QmYxT4LnK8sqLupjbS6eRvu1si7Ly2wFQAqFebxhWntcf6', 'fourth_nft_image_512': 'https://image-proxy.svc.prod.covalenthq.com/cdn-cgi/image/width=512,fit/https://ipfs.io/ipfs/QmYxT4LnK8sqLupjbS6eRvu1si7Ly2wFQAqFebxhWntcf6', 'fourth_nft_image_1024': 'https://image-proxy.svc.prod.covalenthq.com/cdn-cgi/image/width=1024,fit/https://ipfs.io/ipfs/QmYxT4LnK8sqLupjbS6eRvu1si7Ly2wFQAqFebxhWntcf6', 'fifth_nft_image_token_id': '4', 'fifth_nft_image': 'https://ipfs.io/ipfs/QmSg9bPzW9anFYc3wWU5KnvymwkxQTpmqcRSfYj7UmiBa7', 'fifth_nft_image_256': 'https://image-proxy.svc.prod.covalenthq.com/cdn-cgi/image/width=256,fit/https://ipfs.io/ipfs/QmSg9bPzW9anFYc3wWU5KnvymwkxQTpmqcRSfYj7UmiBa7', 'fifth_nft_image_512': 'https://image-proxy.svc.prod.covalenthq.com/cdn-cgi/image/width=512,fit/https://ipfs.io/ipfs/QmSg9bPzW9anFYc3wWU5KnvymwkxQTpmqcRSfYj7UmiBa7', 'fifth_nft_image_1024': 'https://image-proxy.svc.prod.covalenthq.com/cdn-cgi/image/width=1024,fit/https://ipfs.io/ipfs/QmSg9bPzW9anFYc3wWU5KnvymwkxQTpmqcRSfYj7UmiBa7'}, {'chain_id': 1, 'collection_name': 'BoredApeYachtClub', 'collection_address': '0xbc4ca0eda7647a8ab7c2061c2e118a18a936f13d', 'collection_ticker_symbol': 'BAYC', 'opening_date': '2022-04-05', 'volume_wei_day': '2053954202000000000000', 'volume_quote_day': 7171950.5, 'average ...

# %%
######################################
## ༼ つ ◕_◕ ༽つ Input a token ID below:
######################################
tokenId = '1'

## Display the NFT & its traits
token_meta = fetch_token_meta(nft_address, tokenId)
print("The "+token_meta["trait_type"]+" is: "+token_meta["value"])
url = token_meta['image_url'][0]
response = requests.get(url)
Image.open(BytesIO(response.content))
# Out:
# 0                The Mouth is: Grin
# 1    The Clothes is: Vietnam Jacket
# 2         The Background is: Orange
# 3           The Eyes is: Blue Beams
# 4                 The Fur is: Robot
# dtype: object
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=631x631>

# %%
########################################
## Plot floor price & its differences ##
########################################
## Original floor price
fig, axes = plt.subplots(3, 3, sharex=False, figsize=(25,15))
diff0 = data['floor_price_quote_7d']
axes[0,0].plot(diff0); axes[0, 0].set_title('Original 7d floor price')
plot_acf(diff0.dropna(), ax=axes[0, 1])
axes[0,1].axis(xmin=-2, xmax=28)
plot_pacf(diff0.dropna(), ax=axes[0, 2])
axes[0,2].axis(xmin=-2, xmax=28)

## 1st diff
diff1 = data['floor_price_quote_7d'].diff()
axes[1,0].plot(diff1); axes[1, 0].set_title('1st difference of 7d floor price')
plot_acf(diff1.dropna(), ax=axes[1, 1])
axes[1,1].axis(xmin=-2, xmax=28)
plot_pacf(diff1.dropna(), ax=axes[1, 2])
axes[1,2].axis(xmin=-2, xmax=28)

## 2nd diff
## lag goes too far negative => over-differenced!
diff2 = data['floor_price_quote_7d'].diff().diff()
axes[2,0].plot(diff2); axes[2, 0].set_title('2nd difference of 7d floor price')
plot_acf(diff2.dropna(), ax=axes[2, 1])
plot_pacf(diff2.dropna(), ax=axes[2, 2])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 5
#       1 ########################################
#       2 ## Plot floor price & its differences ##
#       3 ########################################
#       4 ## Original floor price
# ----> 5 fig, axes = plt.subplots(3, 3, sharex=False, figsize=(25,15))
#       6 diff0 = data['floor_price_quote_7d']
#       7 axes[0,0].plot(diff0); axes[0, 0].set_title('Original 7d floor price')
#
# NameError: name 'plt' is not defined

# %%
## Stationarity Tests
stationary_test(diff0) ## non-stationary
stationary_test(diff1) ## stationary
stationary_test(diff2)
# Out:
# ADF Statistic: -0.388872
# p-value: 0.911940
# Time-series is non-stationary at 5% significance level. Find the order of difference!
# ADF Statistic: -7.845918
# p-value: 0.000000
# Time-series is stationary at 5% significance level.
# ADF Statistic: -6.891005
# p-value: 0.000000
# Time-series is stationary at 5% significance level.

# %%
############################
## Training testing split ##
############################
train_size = round(len(data)*0.8)

train = data.floor_price_quote_7d[:train_size]
test = data.floor_price_quote_7d[train_size:]

# %%
################################
## Finding optimal parameters ##
################################
model = pm.auto_arima(train, start_p=1, start_q=1,
                      test='adf',       # use adftest to find optimal 'd'
                      max_p=5, max_q=5, 
                      # m=1,             
                      d=None,           
                      seasonal=False,   
                      trace=True, 
                      suppress_warnings=True, 
                      stepwise=True,
                      random_state=123)

print(model.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=5729.675, Time=0.06 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=5735.080, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=5728.820, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=5728.163, Time=0.02 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=5735.909, Time=0.01 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=5729.880, Time=0.02 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=5731.750, Time=0.10 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=5728.210, Time=0.02 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[0] intercept
# Total fit time: 0.250 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  274
# Model:               SARIMAX(0, 1, 1)   Log Likelihood               -2861.081
# Date:                Sat, 12 Nov 2022   AIC                           5728.163
# Time:                        01:03:55   BIC                           5738.991
# Sample:                    04-30-2021   HQIC                          5732.510
#                          - 01-28-2022
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept    764.4151    630.170      1.213      0.225    -470.696    1999.526
# ma.L1          0.1910      0.049      3.901      0.000       0.095       0.287
# sigma2      7.529e+07      0.014   5.38e+09      0.000    7.53e+07    7.53e+07
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):                41.10
# Prob(Q):                              0.91   Prob(JB):                         0.00
# Heteroskedasticity (H):             213.05   Skew:                             0.30
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.80
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.47e+25. Standard errors may be unstable.

# %%
## Check residuals
model.plot_diagnostics(figsize=(14,10))
plt.show()

# %%
################
## Prediction ##
################
pred, ci = model.predict(n_periods = len(test), return_conf_int=True)
idx = np.arange(len(train), len(train) + len(test))

test_pred = pd.Series(pred, index = idx)
lb = pd.Series(ci[:, 0], index = idx)
ub = pd.Series(ci[:, 1], index = idx)

# Plot
plot_train = train.reset_index()
plot_test = pd.DataFrame(test).set_index(idx)
plot_pred = pd.DataFrame(test_pred).set_index(idx)

plt.figure(figsize=(12,5), dpi=100)
plt.plot(plot_train.floor_price_quote_7d, label = "training")
plt.plot(plot_test.floor_price_quote_7d, label = "testing")
plt.plot(plot_pred, label = "prediction")
plt.fill_between(lb.index, lb, ub, color='k', alpha = 0.1)
plt.legend(loc='upper left', fontsize = 12)
plt.title("Forecast vs. actual floor price")
plt.show()

# %%
## Performance metrics
actual = pd.DataFrame(test).reset_index()
actual.columns = ['date','actual']

predict = pd.DataFrame(test_pred).reset_index()
predict.columns = ['date','predict']
accuracy(predict['predict'], actual['actual'])
# Out:
# {'Mean absolute percentage error': nan,
#  'Root mean squared error': nan,
#  'corr': nan}

# %%
print("Abhiram oka booku")
# Out:
# Abhiram oka booku

# %%
# !pip install tensorflow
# Out:
# ^C
